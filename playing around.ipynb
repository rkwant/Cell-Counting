# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from scipy import ndimage
from skimage.morphology import watershed, closing, square, label, disk, reconstruction
from skimage.segmentation import mark_boundaries, join_segmentations, relabel_sequential
from skimage.feature import peak_local_max, corner_peaks
from skimage.io import imread
from skimage.filter import gaussian_filter, threshold_otsu, threshold_isodata, threshold_adaptive, threshold_yen, canny, sobel
from skimage.exposure import adjust_log, adjust_sigmoid, adjust_gamma, equalize_hist, equalize_adapthist, rescale_intensity
from skimage.measure import regionprops
from skimage.color import label2rgb, rgb2gray
from skimage.transform import hough_circle
from skimage.filter.rank import entropy, mean_bilateral
from skimage.restoration import denoise_bilateral
from skimage.measure import find_contours, approximate_polygon, subdivide_polygon
import time
import pickle

from sklearn.grid_search import GridSearchCV
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn import linear_model
from sklearn.mixture import GMM

# %%
path='/Users/richardkwant/Documents/Berkeley/rkwant/Notebook_Pages/Pages/5-066/'
#ath='C:\\Users\\rkwant\\Documents\\Berkeley\\rkwant\\Notebook_Pages\\Pages\\5-066\\'
image=imread(path+'Burke1.tif', as_grey=True)
x,y=image.shape
image = image[x/2+1:,0:y/2]

# %%
figure(1, figsize=(20,10))
clf()
sli = image[:512,:512]
subplot(1,2,1)
imshow(sli)
subplot(1,2,2)
i=6
toshow=sli
toshow=equalize_adapthist(toshow)
toshow=denoise_bilateral(toshow)
toshow= mean_bilateral(toshow, disk(5))

toshow=sli.max()-sli
print threshold_isodata(toshow, 50)
toshow = toshow>threshold_isodata(toshow, 50)
toshow=gaussian_filter(toshow, 2)

imshow(toshow)
show()
# Out:
# 0.315294117647

# %%
figure(2, figsize=(20, 10))
clf()
sli = image[:512,:512]
subplot(121)
imshow(sli, cmap='bone')

subplot(122)
toshow=sli
toshow=equalize_adapthist(toshow)
toshow=denoise_bilateral(toshow)
toshow= mean_bilateral(toshow, disk(5))

im_gaussian = [gaussian_filter(toshow, i) for i in range(1,7,1)]
im_valleys=[]
for a in im_gaussian[0:4]:
    seed = copy(a)
    seed[1:-1, 1:-1] = a.max()
    im_valleys.append(reconstruction(seed, a, method='erosion')-a)

#diff = equalize_hist(diff)

imshow(im_valleys[0], cmap='bone')

# %%
sli.shape
# Out:
# (512, 512)

# %%
figure(2, figsize=(20, 10))
clf()
sli = image[:512,:512]
subplot(121)
imshow(sli, cmap='bone')

subplot(122)
toshow=sli
toshow=equalize_adapthist(toshow)
toshow=denoise_bilateral(toshow)
toshow= mean_bilateral(toshow, disk(5))

diff = gaussian_filter(toshow, 4) - gaussian_filter(toshow, 3)

#diff = equalize_hist(diff)

imshow(diff, cmap='bone')

# %%
contours[100]
# Out:
# array([[  64. ,  457.6],
#        [  63.4,  457. ],
#        [  63.4,  456. ],
#        [  63.4,  455. ],
#        [  64. ,  454.4],
#        [  64.6,  455. ],
#        [  64.6,  456. ],
#        [  64.6,  457. ],
#        [  64. ,  457.6]])
